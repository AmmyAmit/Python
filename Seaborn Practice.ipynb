# %% [markdown]
# ## Seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Statistics/main/CardioGoodFitness-1.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
sb.relplot(x = "Income",y="Age",data = df)

# %%
sb.relplot(x="Product",y="Age",data = df)

# %%
sb.relplot(x="Education",y = "Age",data=df)

# %%
sb.relplot(x="Age",y="Fitness",data = df)

# %%
sb.relplot(x="Fitness",y = "Miles",data=df)

# %%
sb.relplot(x="Fitness",y="Usage",data=df)

# %%
sb.relplot(x="Income",y="Fitness",hue="Age",data=df)

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
sb.relplot(x = "Gender",y="Education",hue="MaritalStatus",data=df)

# %%
sb.relplot(x="Gender",y="Education",size="MaritalStatus",data=df)

# %%
sb.relplot(x="Product",y="Usage",data=df)

# %%
sb.catplot(x = "Product",y="Age",data = df)

# %%
sb.catplot(x= "Product",y="Age",jitter =False,data=df)

# %%
sb.catplot(y = "Income",x = "Education",jitter=False,data=df)

# %%
sb.catplot(x="Miles",y="Income",jitter=False,data=df)

# %%
sb.catplot(x= "Product",y = "Age",kind="swarm",data=df)

# %%
sb.relplot(x = "Income",y= "Age", data=df)

# %%
sb.relplot(x="Product",y="Usage",data=df)

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.shape[1]
# Out:
# 9

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
sb.catplot(x="Product",y="Income",kind="swarm",data=df)

# %%
sb.catplot(x="Product",y="Miles",data= df)

# %%
sb.catplot(x="Product",y="Miles",kind="swarm",data=df)

# %%
sb.catplot(x="Product",y="Miles",jitter=False,data= df)

# %%
sb.catplot(x="Product",y="Miles",hue="Gender",kind="swarm",data=df)

# %%
sb.catplot(x="Product",y="Miles",kind="box",hue="Gender",data=df)

# %%
sb.catplot(x="Product",y="Miles",kind="box",data=df)

# %%
sb.catplot(x="Product",y="Miles",kind="violin",data=df)

# %%
sb.catplot(x="Product",y="Miles",hue="Gender",kind="violin",data=df)

# %%
sb.catplot(x="Product",y="Miles",hue="Gender",kind="violin",split=True,data=df)

# %%
sb.catplot(x="Product",y="Miles",kind="bar",hue="Gender",data=df)

# %%
sb.catplot(x="Product",y="Miles",kind="point",data=df)

# %%
sb.catplot(x="Product",y="Miles",hue="Gender",kind="point",data=df)

# %%
    sb.catplot(x="Product",y="Miles",hue="MaritalStatus",col="Gender",data=df)

# %%
sb.catplot(x="Product",y="Miles",kind="swarm",hue="MaritalStatus",col="Gender",data=df)

# %%
sb.catplot(x="Product",y="Miles",hue="MaritalStatus",col="Gender",aspect=.8,kind="swarm",data=df)

# %% [markdown]
# in the above code aspect is used to change the scal in the horizontal direction

# %%
sb.distplot(df.Age)
# Out:
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sb.distplot(df.Age,rug=True)
# Out:
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sb.distplot(df.Age,kde=False,rug=True)
# Out:
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sb.displot(df.Age,kde=False,rug=True)

# %%
sb.jointplot(x="Age",y="Income",data=df)

# %%
sb.jointplot(x="Age",y="Income",kind="hex",data= df)

# %%
sb.jointplot(x="Age",y="Income",kind="kde",data=df)

# %%
corrmat= df.corr()
plt.subplots()
sb.heatmap(corrmat)
# Out:
# <AxesSubplot:>

# %%
sb.pairplot(df)

# %%
sb.catplot(x="Age",y="Income",kind="swarm",aspect=2,data=df)
# Out:
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\amita\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
